# %%
import paarti.utils.maos_utils as mu
import paarti.utils.koa_utils as ku
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
from pathlib import Path
from astropy.io import fits

# %% [markdown]
# #### Load in centroids and image metadata

# %%
centroids_x, centroids_y = np.loadtxt("/Users/bdigia/work/ao/airopa_input/AdamKeckData/MoreKeck/centroids2019.txt", 
                                       usecols=(1, 2), 
                                       unpack=True)
filenames = np.loadtxt("/Users/bdigia/work/ao/airopa_input/AdamKeckData/MoreKeck/centroids2019.txt", 
                        usecols=(3), dtype=str)
